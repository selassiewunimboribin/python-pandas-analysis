# %%
import pandas as pd
poke = pd.read_csv(r'C:\Users\DELL\Downloads\datasets\POKEMON.csv')
poke
# Out:
#        #                   Name   Type 1  Type 2  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison  45      49       49
# 1      2                Ivysaur    Grass  Poison  60      62       63
# 2      3               Venusaur    Grass  Poison  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison  80     100      123
# 4      4             Charmander     Fire     NaN  39      52       43
# ..   ...                    ...      ...     ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark  80     160       60
# 799  721              Volcanion     Fire   Water  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary  summed_rows
# ...

# %%
poke.head(3)
# Out:
#    #       Name Type 1  Type 2  Total  HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 0  1  Bulbasaur  Grass  Poison    318  45      49       49       65       65
# 1  2    Ivysaur  Grass  Poison    405  60      62       63       80       80
# 2  3   Venusaur  Grass  Poison    525  80      82       83      100      100
#
#    Speed  Generation  Legendary
# 0     45           1      False
# 1     60           1      False
# 2     80           1      False

# %%
poke.columns
# Out:
# Index(['#', 'Name', 'Type 1', 'Type 2', 'HP', 'Attack', 'Defense', 'Sp. Atk',
#        'Sp. Def', 'Speed', 'Generation', 'Legendary', 'summed_rows'],
#       dtype='object')

# %%
poke[['Name', 'Type 1']][0:5]
# Out:
#                     Name Type 1
# 0              Bulbasaur  Grass
# 1                Ivysaur  Grass
# 2               Venusaur  Grass
# 3  VenusaurMega Venusaur  Grass
# 4             Charmander   Fire

# %%
poke.iloc[0:801, 4:10] # poke.iloc[rows, columns]
# Out:
#      HP  Attack  Defense  Sp. Atk  Sp. Def  Speed
# 0    45      49       49       65       65     45
# 1    60      62       63       80       80     60
# 2    80      82       83      100      100     80
# 3    80     100      123      122      120     80
# 4    39      52       43       60       50     65
# ..   ..     ...      ...      ...      ...    ...
# 795  50     100      150      100      150     50
# 796  50     160      110      160      110    110
# 797  80     110       60      150      130     70
# 798  80     160       60      170      130     80
# 799  80     110      120      130       90     70
#
# [800 rows x 6 columns]

# %%
 poke.iloc[4] # iloc locates rows in a data using indexing
# Out:
# #                      4
# Name          Charmander
# Type 1              Fire
# Type 2               NaN
# Total                309
# HP                    39
# Attack                52
# Defense               43
# Sp. Atk               60
# Sp. Def               50
# Speed                 65
# Generation             1
# Legendary          False
# Name: 4, dtype: object

# %%
# read a specific location
poke.iloc[796, 3]
# Out:
# 'Fairy'

# %%
poke.loc[poke['Name']=='Blastoise'] #locates data using names of data
# Out:
#     #       Name Type 1 Type 2  Total  HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 11  9  Blastoise  Water    NaN    530  79      83      100       85      105
#
#     Speed  Generation  Legendary
# 11     78           1      False

# %%
poke.loc[:, 'Name']
# Out:
# 0                  Bulbasaur
# 1                    Ivysaur
# 2                   Venusaur
# 3      VenusaurMega Venusaur
# 4                 Charmander
#                ...
# 795                  Diancie
# 796      DiancieMega Diancie
# 797      HoopaHoopa Confined
# 798       HoopaHoopa Unbound
# 799                Volcanion
# Name: Name, Length: 800, dtype: object

# %%
for index, row in poke.iterrows():
    print(f"Row {index}: '{row['Name']}'")
# Out:
# Row 0: 'Bulbasaur'
# Row 1: 'Ivysaur'
# Row 2: 'Venusaur'
# Row 3: 'VenusaurMega Venusaur'
# Row 4: 'Charmander'
# Row 5: 'Charmeleon'
# Row 6: 'Charizard'
# Row 7: 'CharizardMega Charizard X'
# Row 8: 'CharizardMega Charizard Y'
# Row 9: 'Squirtle'
# Row 10: 'Wartortle'
# Row 11: 'Blastoise'
# Row 12: 'BlastoiseMega Blastoise'
# Row 13: 'Caterpie'
# Row 14: 'Metapod'
# Row 15: 'Butterfree'
# Row 16: 'Weedle'
# Row 17: 'Kakuna'
# Row 18: 'Beedrill'
# Row 19: 'BeedrillMega Beedrill'
# Row 20: 'Pidgey'
# Row 21: 'Pidgeotto'
# Row 22: 'Pidgeot'
# Row 23: 'PidgeotMega Pidgeot'
# Row 24: 'Rattata'
# Row 25: 'Raticate'
# Row 26: 'Spearow'
# Row 27: 'Fearow'
# Row 28: 'Ekans'
# Row 29: 'Arbok'
# Row 30: 'Pikachu'
# Row 31: 'Raichu'
# Row 32: 'Sandshrew'
# Row 33: 'Sandslash'
# Row 34: 'Nidoran♀'
# Row 35: 'Nidorina'
# Row 36: 'Nidoqueen'
# Row 37: 'Nidoran♂'
# Row 38: 'Nidorino'
# Row 39: 'Nidoking'
# Row 40: 'Clefairy'
# Row 41: 'Clefable'
# Row 42: 'Vulpix'
# Row 43: 'Ninetales'
# ...

# %%
poke.loc[poke['Type 1'] == 'Fire' ]
# Out:
#        #                       Name Type 1    Type 2   HP  Attack  Defense  \
# 4      4                 Charmander   Fire       NaN   39      52       43
# 5      5                 Charmeleon   Fire       NaN   58      64       58
# 6      6                  Charizard   Fire    Flying   78      84       78
# 7      6  CharizardMega Charizard X   Fire    Dragon   78     130      111
# 8      6  CharizardMega Charizard Y   Fire    Flying   78     104       78
# 42    37                     Vulpix   Fire       NaN   38      41       40
# 43    38                  Ninetales   Fire       NaN   73      76       75
# 63    58                  Growlithe   Fire       NaN   55      70       45
# 64    59                   Arcanine   Fire       NaN   90     110       80
# 83    77                     Ponyta   Fire       NaN   50      85       55
# 84    78                   Rapidash   Fire       NaN   65     100       70
# ...

# %%
poke.loc[poke['Type 1'] == 'Fire' ].filter(items = ['Name', 'Type 1', 'Total', 'HP']).sort_values(by = 'Total', ascending = True)
# Out:
#                           Name Type 1  Total   HP
# 236                     Slugma   Fire    250   40
# 42                      Vulpix   Fire    299   38
# 352                      Numel   Fire    305   60
# 721                   Fennekin   Fire    307   40
# 557                      Tepig   Fire    308   65
# 4                   Charmander   Fire    309   39
# 435                   Chimchar   Fire    309   44
# 169                  Cyndaquil   Fire    309   39
# 276                    Torchic   Fire    310   45
# 614                   Darumaka   Fire    315   70
# 572                    Pansear   Fire    316   50
# 63                   Growlithe   Fire    350   55
# 259                      Magby   Fire    365   45
# 735                     Litleo   Fire    369   62
# 730                Fletchinder   Fire    382   62
# 5                   Charmeleon   Fire    405   58
# 436                   Monferno   Fire    405   64
# 170                    Quilava   Fire    405   58
# ...

# %%
poke.describe()
# Out:
#                 #      Total          HP      Attack     Defense     Sp. Atk  \
# count  800.000000  800.00000  800.000000  800.000000  800.000000  800.000000
# mean   362.813750  435.10250   69.258750   79.001250   73.842500   72.820000
# std    208.343798  119.96304   25.534669   32.457366   31.183501   32.722294
# min      1.000000  180.00000    1.000000    5.000000    5.000000   10.000000
# 25%    184.750000  330.00000   50.000000   55.000000   50.000000   49.750000
# 50%    364.500000  450.00000   65.000000   75.000000   70.000000   65.000000
# 75%    539.250000  515.00000   80.000000  100.000000   90.000000   95.000000
# max    721.000000  780.00000  255.000000  190.000000  230.000000  194.000000
#
#           Sp. Def       Speed  Generation
# count  800.000000  800.000000   800.00000
# mean    71.902500   68.277500     3.32375
# std     27.828916   29.060474     1.66129
# min     20.000000    5.000000     1.00000
# 25%     50.000000   45.000000     2.00000
# ...

# %%
poke.groupby('Name').median('Total')
# Out:
#                              #  Total     HP  Attack  Defense  Sp. Atk  \
# Name
# Abomasnow                460.0  494.0   90.0    92.0     75.0     92.0
# AbomasnowMega Abomasnow  460.0  594.0   90.0   132.0    105.0    132.0
# Abra                      63.0  310.0   25.0    20.0     15.0    105.0
# Absol                    359.0  465.0   65.0   130.0     60.0     75.0
# AbsolMega Absol          359.0  565.0   65.0   150.0     60.0    115.0
# ...                        ...    ...    ...     ...      ...      ...
# Zoroark                  571.0  510.0   60.0   105.0     60.0    120.0
# Zorua                    570.0  330.0   40.0    65.0     40.0     80.0
# Zubat                     41.0  245.0   40.0    45.0     35.0     30.0
# Zweilous                 634.0  420.0   72.0    85.0     70.0     65.0
# Zygarde50% Forme         718.0  600.0  108.0   100.0    121.0     81.0
#
#                          Sp. Def  Speed  Generation  Legendary
# Name
# ...

# %%
poke.sort_values(by = ['Name', 'Total'], ascending = [1, 0])
# Out:
#        #                     Name   Type 1  Type 2  Total   HP  Attack  \
# 510  460                Abomasnow    Grass     Ice    494   90      92
# 511  460  AbomasnowMega Abomasnow    Grass     Ice    594   90     132
# 68    63                     Abra  Psychic     NaN    310   25      20
# 392  359                    Absol     Dark     NaN    465   65     130
# 393  359          AbsolMega Absol     Dark     NaN    565   65     150
# ..   ...                      ...      ...     ...    ...  ...     ...
# 632  571                  Zoroark     Dark     NaN    510   60     105
# 631  570                    Zorua     Dark     NaN    330   40      65
# 46    41                    Zubat   Poison  Flying    245   40      45
# 695  634                 Zweilous     Dark  Dragon    420   72      85
# 794  718         Zygarde50% Forme   Dragon  Ground    600  108     100
#
#      Defense  Sp. Atk  Sp. Def  Speed  Generation  Legendary
# ...

# %%
poke['summed_rows'] = poke.iloc[0:801, 4:10].sum(axis = 1) # adding rows

# %%
poke
# Out:
#        #                   Name   Type 1  Type 2  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison  45      49       49
# 1      2                Ivysaur    Grass  Poison  60      62       63
# 2      3               Venusaur    Grass  Poison  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison  80     100      123
# 4      4             Charmander     Fire     NaN  39      52       43
# ..   ...                    ...      ...     ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark  80     160       60
# 799  721              Volcanion     Fire   Water  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary  summed_rows
# ...

# %%
poke.to_csv('POKEMON.csv', index = False)

# %%
poke.loc[(poke['Type 1'] == 'Grass') & (poke['Type 2'] == 'Poison') & (poke['HP'] > 75)]#.filter(items = ['Name', 'Type 1', 'Type 2', 'Speed', 'Generation']).sort_values(by = 'Generation', ascending = True)
# Out:
#        #                   Name Type 1  Type 2   HP  Attack  Defense  Sp. Atk  \
# 2      3               Venusaur  Grass  Poison   80      82       83      100
# 3      3  VenusaurMega Venusaur  Grass  Poison   80     100      123      122
# 77    71             Victreebel  Grass  Poison   80     105       65      100
# 652  591              Amoonguss  Grass  Poison  114      85       70       85
#
#      Sp. Def  Speed  Generation  Legendary  summed_rows
# 2        100     80           1      False          525
# 3        120     80           1      False          625
# 77        70     70           1      False          490
# 652       80     30           5      False          464

# %%
non_mega_part = poke.loc[~poke['Name'].str.contains('Mega')]
non_mega_part
# Out:
#        #                 Name   Type 1  Type 2   HP  Attack  Defense  Sp. Atk  \
# 0      1            Bulbasaur    Grass  Poison   45      49       49       65
# 1      2              Ivysaur    Grass  Poison   60      62       63       80
# 2      3             Venusaur    Grass  Poison   80      82       83      100
# 4      4           Charmander     Fire     NaN   39      52       43       60
# 5      5           Charmeleon     Fire     NaN   58      64       58       80
# ..   ...                  ...      ...     ...  ...     ...      ...      ...
# 794  718     Zygarde50% Forme   Dragon  Ground  108     100      121       81
# 795  719              Diancie     Rock   Fairy   50     100      150      100
# 797  720  HoopaHoopa Confined  Psychic   Ghost   80     110       60      150
# 798  720   HoopaHoopa Unbound  Psychic    Dark   80     160       60      170
# 799  721            Volcanion     Fire   Water   80     110      120      130
#
# ...

# %%
non_mega_part.to_csv('non_mega_part.csv', index = False)

# %%
filtered = []

for index, row in poke.iterrows():
    if row['HP'] >= 100:
        filtered.append(index)  # Store the row index, not the HP value

print(poke.loc[filtered].filter(items=['Name', 'HP']).sort_values(by='HP', ascending=True))

# print(boolean)
#print(len(boolean))
# Out:
#                         Name   HP
# 267                Tyranitar  100
# 427                  Jirachi  100
# 268  TyranitarMega Tyranitar  100
# 548                  Manaphy  100
# 516                Tangrowth  100
# ..                       ...  ...
# 655                Alomomola  165
# 351                  Wailord  170
# 217                Wobbuffet  190
# 121                  Chansey  250
# 261                  Blissey  255
#
# [99 rows x 2 columns]

# %%
poke.loc[poke['HP'] >= 100].sort_values(by = 'HP', ascending = True)
# Out:
#        #                     Name   Type 1   Type 2   HP  Attack  Defense  \
# 267  248                Tyranitar     Rock     Dark  100     134      110
# 427  385                  Jirachi    Steel  Psychic  100     100      100
# 268  248  TyranitarMega Tyranitar     Rock     Dark  100     164      150
# 548  490                  Manaphy    Water      NaN  100     100      100
# 516  465                Tangrowth    Grass      NaN  100     100      125
# ..   ...                      ...      ...      ...  ...     ...      ...
# 655  594                Alomomola    Water      NaN  165      75       80
# 351  321                  Wailord    Water      NaN  170      90       45
# 217  202                Wobbuffet  Psychic      NaN  190      33       58
# 121  113                  Chansey   Normal      NaN  250       5        5
# 261  242                  Blissey   Normal      NaN  255      10       10
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary  summed_rows
# ...

# %%
poke.loc[(poke['Type 1'].str.contains('Fire|Grass')) & (poke['Type 2'].str.contains('Water'))]
# Out:
#        #       Name Type 1 Type 2  HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 799  721  Volcanion   Fire  Water  80     110      120      130       90
#
#      Speed  Generation  Legendary  summed_rows
# 799     70           6       True          600

# %%
poke.loc[poke['Name'].str.contains('Pi')]
# Out:
#        #                     Name    Type 1    Type 2   HP  Attack  Defense  \
# 20    16                   Pidgey    Normal    Flying   40      45       40
# 21    17                Pidgeotto    Normal    Flying   63      60       55
# 22    18                  Pidgeot    Normal    Flying   83      80       75
# 23    18      PidgeotMega Pidgeot    Normal    Flying   83      80       80
# 30    25                  Pikachu  Electric       NaN   35      55       40
# 136  127                   Pinsir       Bug       NaN   65     125      100
# 137  127        PinsirMega Pinsir       Bug    Flying   65     155      120
# 186  172                    Pichu  Electric       NaN   20      40       15
# 219  204                   Pineco       Bug       NaN   50      65       90
# 239  221                Piloswine       Ice    Ground  100     100       80
# 438  393                   Piplup     Water       NaN   53      51       53
# ...

# %%
poke.loc[poke['Type 1'] == 'Fire', 'Type 1'] = 'flammer' # conditional changing
poke
# Out:
#        #                   Name   Type 1  Type 2  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison  45      49       49
# 1      2                Ivysaur    Grass  Poison  60      62       63
# 2      3               Venusaur    Grass  Poison  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison  80     100      123
# 4      4             Charmander  flammer     NaN  39      52       43
# ..   ...                    ...      ...     ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark  80     160       60
# 799  721              Volcanion  flammer   Water  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary  summed_rows
# ...

# %%
poke['Type 1'] = poke['Type 1'].replace('flammer', 'Flamer')# conditional changing

# %%
poke
# Out:
#        #                   Name   Type 1  Type 2  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison  45      49       49
# 1      2                Ivysaur    Grass  Poison  60      62       63
# 2      3               Venusaur    Grass  Poison  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison  80     100      123
# 4      4             Charmander   Flamer     NaN  39      52       43
# ..   ...                    ...      ...     ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark  80     160       60
# 799  721              Volcanion   Flamer   Water  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary  summed_rows
# ...

# %%
poke.loc[poke['summed_rows'] >= 500, ['Generation', 'Legendary']] = ['test 1', 'test 2']
poke
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_596\2856931562.py:1: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'test 1' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   poke.loc[poke['summed_rows'] >= 500, ['Generation', 'Legendary']] = ['test 1', 'test 2']
# C:\Users\DELL\AppData\Local\Temp\ipykernel_596\2856931562.py:1: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'test 2' has dtype incompatible with bool, please explicitly cast to a compatible dtype first.
#   poke.loc[poke['summed_rows'] >= 500, ['Generation', 'Legendary']] = ['test 1', 'test 2']
#        #                   Name   Type 1  Type 2  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison  45      49       49
# 1      2                Ivysaur    Grass  Poison  60      62       63
# ...

# %%
poke
# Out:
#        #                   Name   Type 1  Type 2  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison  45      49       49
# 1      2                Ivysaur    Grass  Poison  60      62       63
# 2      3               Venusaur    Grass  Poison  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison  80     100      123
# 4      4             Charmander     Fire     NaN  39      52       43
# ..   ...                    ...      ...     ...  ..     ...      ...
# 795  719                Diancie     Rock   fairy  50     100      150
# 796  719    DiancieMega Diancie     Rock   fairy  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark  80     160       60
# 799  721              Volcanion     Fire   Water  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary  summed_rows
# ...

# %%
poke['Type 2'] = poke['Type 2'].replace('Fairy', 'fairy')

# %%
poke
# Out:
#        #                   Name   Type 1  Type 2  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison  45      49       49
# 1      2                Ivysaur    Grass  Poison  60      62       63
# 2      3               Venusaur    Grass  Poison  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison  80     100      123
# 4      4             Charmander     Fire     NaN  39      52       43
# ..   ...                    ...      ...     ...  ..     ...      ...
# 795  719                Diancie     Rock   fairy  50     100      150
# 796  719    DiancieMega Diancie     Rock   fairy  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark  80     160       60
# 799  721              Volcanion     Fire   Water  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary  summed_rows
# ...

# %%
groups = poke.groupby(['Type 1', 'Type 2']).count()
groups
# Out:
#                     #  Name  HP  Attack  Defense  Sp. Atk  Sp. Def  Speed  \
# Type 1   Type 2
# Bug      Electric   2     2   2       2        2        2        2      2
#          Fighting   2     2   2       2        2        2        2      2
#          Fire       2     2   2       2        2        2        2      2
#          Flying    14    14  14      14       14       14       14     14
#          Ghost      1     1   1       1        1        1        1      1
#          Grass      6     6   6       6        6        6        6      6
#          Ground     2     2   2       2        2        2        2      2
#          Poison    12    12  12      12       12       12       12     12
#          Rock       3     3   3       3        3        3        3      3
#          Steel      7     7   7       7        7        7        7      7
#          Water      1     1   1       1        1        1        1      1
# ...

# %%
pd.set_option('display.max.rows', 137)

# %%
groups.to_csv('groups.csv')

# %%
filtered = []
for row in poke.HP:
    if row >= 100:
        filtered.append(row)  # This adds the HP value, not the row index
print(poke.loc[filtered])
# Out:
#        #        Name    Type 1  Type 2   HP  Attack  Defense  Sp. Atk  \
# 115  107  Hitmonchan  Fighting     NaN   50     105       79       35
# 140  130    Gyarados     Water  Flying   95     125       79       60
# 105   97       Hypno   Psychic     NaN   85      73       70       73
# 105   97       Hypno   Psychic     NaN   85      73       70       73
# 250  231      Phanpy    Ground     NaN   90      60       60       40
# ..   ...         ...       ...     ...  ...     ...      ...      ...
# 101   94      Gengar     Ghost  Poison   60      65       60      130
# 123  115  Kangaskhan    Normal     NaN  105      95       80       40
# 126  117      Seadra     Water     NaN   55      65       95       95
# 126  117      Seadra     Water     NaN   55      65       95       95
# 108  100     Voltorb  Electric     NaN   40      30       50       55
#
#      Sp. Def  Speed  Generation  Legendary  summed_rows
# 115      110     76           1      False          455
# ...
